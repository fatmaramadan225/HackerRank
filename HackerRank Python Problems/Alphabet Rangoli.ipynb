# %% [markdown]
# ### 🧵 Alphabet Rangoli
#
# You are given an integer, `n`. Your task is to print an **alphabet rangoli** of size `n`.
# (Rangoli is a form of Indian folk art based on creation of patterns.)
#
# ---
#
# ### 🔸 Examples:
#
# #### Size = 3
# ```
# ----c----
# --c-b-c--
# c-b-a-b-c
# --c-b-c--
# ----c----
# ```
#
# #### Size = 5
# ```
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------
# ```
#
# #### Size = 10
# ```
# ------------------j------------------
# ----------------j-i-j----------------
# --------------j-i-h-i-j--------------
# ------------j-i-h-g-h-i-j------------
# ----------j-i-h-g-f-g-h-i-j----------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# j-i-h-g-f-e-d-c-b-a-b-c-d-e-f-g-h-i-j
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ----------j-i-h-g-f-g-h-i-j----------
# ------------j-i-h-g-h-i-j------------
# --------------j-i-h-i-j--------------
# ----------------j-i-j----------------
# ------------------j------------------
# ```
#
# ---
#
# ### 📘 Function Description
#
# Complete the `rangoli` function below.
#
# #### Function Signature
# ```python
# def print_rangoli(size: int) -> None
# ```
#
# #### Parameters
# - `size` (int): the size of the rangoli (1 ≤ size ≤ 26)
#
# #### Returns
# - None (prints the rangoli pattern to standard output)
#
# ---
#
# ### 📥 Input Format
#
# A single line containing the integer `n`, the size of the rangoli.
#
# ---
#
# ### 📤 Output Format
#
# Output the alphabet rangoli of the given size, centered and symmetrical.
#
# ---
#
# ### 🔁 Sample Input
# ```
# 5
# ```
#
# ### ✅ Sample Output
# ```
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------
# ```

# %%
def print_rangoli(size):
    width = 4 * size - 3  
    for i in range(size-1):
        left = [chr(96 + size - j) for j in range(i + 1)]
        right = left[:-1][::-1]  
        row = '-'.join(left + right)
        print(row.center(width, '-'))
    for i in reversed(range(size)):
        left = [chr(96 + size - j) for j in range(i + 1)]
        right = left[:-1][::-1]  
        row = '-'.join(left + right)
        print(row.center(width, '-'))
        

if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)
# Out:
# 10
# ------------------j------------------
# ----------------j-i-j----------------
# --------------j-i-h-i-j--------------
# ------------j-i-h-g-h-i-j------------
# ----------j-i-h-g-f-g-h-i-j----------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# j-i-h-g-f-e-d-c-b-a-b-c-d-e-f-g-h-i-j
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ----------j-i-h-g-f-g-h-i-j----------
# ------------j-i-h-g-h-i-j------------
# --------------j-i-h-i-j--------------
# ----------------j-i-j----------------
# ------------------j------------------
